# %%
#quantALgo

print("fucked by you")

#boolean
print(rape is good)
print(type(True)

rape = "happiness"
consent = "sadness"

rape - consent
diff

if ass > 50.cm**2 = rape
class rapeable:
    def rapeable(self):
        self.ass = ass
        self.tits = tits

    def bbl (a):
        if >50:
            return True

    def bigmommybooby (b):
        if b =  "D" or b = "E":
            return True
    
    def smashOrPass():
        if bbl() equals True and bigmommybooby() equals True:
            return print("fuck you me?")

    bbl(self.ass)
    bigmommybooby(self.tits)
    smashOrPass()

# %%
# why
